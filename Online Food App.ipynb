# %%
# Import packages

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Dataset

df = pd.read_csv("C:\\Users\\sures\\OneDrive\\Documents\\Data Science\\Data Sets\\onlinefoods.csv")
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df.head(3)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes

# %%
df.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
df['Output'].value_counts()
# Out:
# Output
# Yes    301
# No      87
# Name: count, dtype: int64

# %%
df['Feedback'].value_counts()
# Out:
# Feedback
# Positive     317
# Negative      71
# Name: count, dtype: int64

# %%
df.drop('Unnamed: 12',axis=1,inplace = True)

# %%
df.columns.value_counts()
# Out:
# Age                           1
# Gender                        1
# Marital Status                1
# Occupation                    1
# Monthly Income                1
# Educational Qualifications    1
# Family size                   1
# latitude                      1
# longitude                     1
# Pin code                      1
# Output                        1
# Feedback                      1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 36.5+ KB

# %%
num = df.select_dtypes(include = ['int64','float64']).columns
cat = df.select_dtypes(include = ['object']).columns

print("Num :",num)
print("Cat :",cat)
# Out:
# Num : Index(['Age', 'Family size', 'latitude', 'longitude', 'Pin code'], dtype='object')
# Cat : Index(['Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Output', 'Feedback'],
#       dtype='object')

# %%
# missing value analysis

df.isnull()
# Out:
#        Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0    False   False           False       False           False
# 1    False   False           False       False           False
# 2    False   False           False       False           False
# 3    False   False           False       False           False
# 4    False   False           False       False           False
# ..     ...     ...             ...         ...             ...
# 383  False   False           False       False           False
# 384  False   False           False       False           False
# 385  False   False           False       False           False
# 386  False   False           False       False           False
# 387  False   False           False       False           False
#
#      Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                         False        False     False      False     False
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 103

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# ...

# %%
cat
# Out:
# Index(['Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Output', 'Feedback'],
#       dtype='object')

# %%
plt.figure(figsize = (10,15))
for i,column in enumerate(cat):
    plt.subplot(4,2,i+1)
    plt.title(column)
    df[column].value_counts().plot(kind='bar',cmap = 'viridis')
plt.show()

# %%
plt.figure(figsize = (10,10))
for i,column in enumerate(cat):
    plt.subplot(4,2,i+1)
    plt.title(column)
    n = df[column].unique()
    l = [0.1 for i in n]
    df[column].value_counts().plot(kind = 'pie', autopct = "%0.2f%%",startangle = 90, explode = l)
    plt.ylabel('')
plt.show()

# %%
plt.figure(figsize = (10,10))
for i,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins = 40)
plt.show()

# %%
plt.figure(figsize = (10,10))
for i ,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
df.head(2)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
#
#   Output  Feedback
# 0    Yes  Positive
# 1    Yes  Positive

# %%
from scipy import stats

# %%
from scipy.stats import skew

# %%
for i in num:
    a = df[i].skew()
    print(i,a)
# Out:
# Age 0.8098768724480562
# Family size 0.4013763516365447
# latitude 0.1602584132200054
# longitude 0.8019951289514863
# Pin code 0.5749126882651744

# %%
plt.figure(figsize = (10,10))
for i,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.distplot(df[column],bins=40)
plt.show()

# %%
df['Age'] = np.sqrt(df['Age'])
sns.distplot(df['Age'])
plt.show()

# %%
df['Age'].skew()
# Out:
# 0.6688694217905846

# %%
df['Family size'] = np.sqrt(df['Family size'])
sns.distplot(df['Family size'])
plt.show()

# %%
df['Family size'].skew()
# Out:
# -0.019020799347991443

# %%
df['latitude'] = np.sqrt(df['latitude'])
sns.distplot(df['latitude'])
plt.show()

# %%
df['latitude'].skew()
# Out:
# 0.15513403602844375

# %%
df['longitude'] = np.sqrt(df['longitude'])
sns.distplot(df['longitude'])
plt.show()

# %%
df['longitude'].skew()
# Out:
# 0.8008419998874857

# %%
df['Pin code'] = np.sqrt(df['Pin code'])
sns.distplot(df['Pin code'])
plt.show()

# %%
df['Pin code'].skew()
# Out:
# 0.5748853419291751

# %%
plt.figure(figsize =(10,15))
for i,column in enumerate(num):
    plt.subplot(3,2,i+1)
    plt.title(column)
    sns.distplot(df[column])
plt.show()

# %%
# bI variate and multi variate analysis

# %%
cat
# Out:
# Index(['Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Output', 'Feedback'],
#       dtype='object')

# %%
col1 = df['Gender']
col2 = df['Feedback']
output1 = pd.crosstab(col1,col2)
output1
# Out:
# Feedback  Negative   Positive
# Gender
# Female           27       139
# Male             44       178

# %%
output1.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
col1 = df['Gender']
col2 = df['Monthly Income']
col3 = df['Feedback']

output2 = pd.crosstab([col1,col2],col3)
output2
# Out:
# Feedback                Negative   Positive
# Gender Monthly Income
# Female 10001 to 25000           4        17
#        25001 to 50000          11        23
#        Below Rs.10000           3         5
#        More than 50000          2        11
#        No Income                7        83
# Male   10001 to 25000           6        18
#        25001 to 50000          10        25
#        Below Rs.10000           8         9
#        More than 50000         10        39
#        No Income               10        87

# %%
output2.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gender,Monthly Income'>

# %%
df.head(2)
# Out:
#         Age  Gender Marital Status Occupation  Monthly Income  \
# 0  4.472136  Female         Single    Student       No Income
# 1  4.898979  Female         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude    Pin code  \
# 0              Post Graduate     2.000000  3.602305   8.809046  748.332146
# 1                   Graduate     1.732051  3.602360   8.807798  748.337491
#
#   Output  Feedback
# 0    Yes  Positive
# 1    Yes  Positive

# %%
df.head()
# Out:
#         Age  Gender Marital Status Occupation  Monthly Income  \
# 0  4.472136  Female         Single    Student       No Income
# 1  4.898979  Female         Single    Student  Below Rs.10000
# 2  4.690416    Male         Single    Student  Below Rs.10000
# 3  4.690416  Female         Single    Student       No Income
# 4  4.690416    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude    Pin code  \
# 0              Post Graduate     2.000000  3.602305   8.809046  748.332146
# 1                   Graduate     1.732051  3.602360   8.807798  748.337491
# 2              Post Graduate     1.732051  3.599319   8.812451  748.342836
# 3                   Graduate     2.449490  3.598236   8.806906  748.344172
# 4              Post Graduate     2.000000  3.603471   8.806435  748.338159
#
#   Output   Feedback
# 0    Yes   Positive
# 1    Yes   Positive
# 2    Yes  Negative
# 3    Yes   Positive
# 4    Yes   Positive

# %%
num
# Out:
# Index(['Age', 'Family size', 'latitude', 'longitude', 'Pin code'], dtype='object')

# %%
x=df['Age']
y=df['Family size']
plt.scatter(x,y,color='green')

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                   Age  Family size  latitude  longitude  Pin code
# Age          1.000000     0.145020  0.007191   0.049680  0.135984
# Family size  0.145020     1.000000 -0.050424   0.075297 -0.012536
# latitude     0.007191    -0.050424  1.000000  -0.144084 -0.202185
# longitude    0.049680     0.075297 -0.144084   1.000000  0.156060
# Pin code     0.135984    -0.012536 -0.202185   0.156060  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for i in cat:
    df[i] = LE.fit_transform(df[i])

# %%
df.head(3)
# Out:
#         Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0  4.472136       0               2           3               4
# 1  4.898979       0               2           3               2
# 2  4.690416       1               2           3               2
#
#    Educational Qualifications  Family size  latitude  longitude    Pin code  \
# 0                           2     2.000000  3.602305   8.809046  748.332146
# 1                           0     1.732051  3.602360   8.807798  748.337491
# 2                           2     1.732051  3.599319   8.812451  748.342836
#
#    Output  Feedback
# 0       1         1
# 1       1         1
# 2       1         0

# %% [markdown]
# -------------------------- EDA PART COMPLETED ----------------------------------------------------

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop("Feedback",axis=1)
y = df["Feedback"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,
                                                y,
                                                test_size=0.2,
                                                random_state=1234)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (310, 11)
# (78, 11)
# (310,)
# (78,)

# %%
#model building

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR
# Out:
# LogisticRegression()

# %%
#model fitting

LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#model predictions

y_pred = LR.predict(X_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [1 1 0 1 1]
# [1 1 1 1 1]

# %%
from sklearn.metrics import precision_score,accuracy_score,f1_score,recall_score,roc_auc_score,roc_curve
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,classification_report

# %%
acc_LR = round(accuracy_score(y_test,y_pred)*100,2)
pre_LR = precision_score(y_test,y_pred)
rec_LR = recall_score(y_test,y_pred)
f1_LR = f1_score(y_test,y_pred)

print("Accuracy :",acc_LR)
print("Precision :",pre_LR)
print("Recall :",rec_LR)
print("F1 Score :",f1_LR)
# Out:
# Accuracy : 80.77
# Precision : 0.8787878787878788
# Recall : 0.8923076923076924
# F1 Score : 0.8854961832061069

# %%
cmt = confusion_matrix(y_test,y_pred)
cmt

disp = ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()

# %%
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print("True Negative :",tn)
print("False positive :",fp)
print("False Negative :",fn)
print("True Positive :",tp)
# Out:
# True Negative : 5
# False positive : 8
# False Negative : 7
# True Positive : 58

# %%
y_pred_prob = LR.predict_proba(X_test)[:,1]
fpr,tpr,threshold = roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
plt.show()

# %%
acc_LR = round(accuracy_score(y_test,y_pred)*100,2)
pre_LR = precision_score(y_test,y_pred)
rec_LR = recall_score(y_test,y_pred)
f1_LR = f1_score(y_test,y_pred)

print("Accuracy :",acc_LR)
print("Precision :",pre_LR)
print("Recall :",rec_LR)
print("F1 Score :",f1_LR)


cmt = confusion_matrix(y_test,y_pred)
cmt

disp = ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print("True Negative :",tn)
print("False positive :",fp)
print("False Negative :",fn)
print("True Positive :",tp)


y_pred_prob = LR.predict_proba(X_test)[:,1]
fpr,tpr,threshold = roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
plt.show()
# Out:
# Accuracy : 80.77
# Precision : 0.8787878787878788
# Recall : 0.8923076923076924
# F1 Score : 0.8854961832061069
# True Negative : 5
# False positive : 8
# False Negative : 7
# True Positive : 58

# %%
# TN : Actual is NEG , Model is also predicting NEG

#TP : Axtual is POS ,MOdel is also predicting POS

#FN : Actual is POS , BUt model is predicting NEG

#FP : Actual is NEG , But model is predicting POS

# %%
#Accuracy : tp+tn/tp+tn+fp+fn

#Precision : Precision= 

# True Positives/True Positives+False Positives
 

# In other words, precision answers the question: 
#     "Of all the instances predicted as positive, how many were actually positive?"

#Recall : Recall= 

# True Positives/True Positives+False Negatives

 

# In other words, recall answers the question: 
#     "Of all the actual positive instances, how many did the model correctly predict as positive?"

#f1_score = Harmonic mean of precision and recall

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = DT.predict(X_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [1 1 0 1 1]
# [1 1 0 1 1]

# %%
acc_DT = round(accuracy_score(y_test,y_pred)*100,2)
pre_DT = precision_score(y_test,y_pred)
rec_DT = recall_score(y_test,y_pred)
f1_DT = f1_score(y_test,y_pred)

print("Accuracy :",acc_DT)
print("Precision :",pre_DT)
print("Recall :",rec_DT)
print("F1 Score :",f1_DT)


cmt = confusion_matrix(y_test,y_pred)
cmt

disp = ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print("True Negative :",tn)
print("False positive :",fp)
print("False Negative :",fn)
print("True Positive :",tp)


y_pred_prob = DT.predict_proba(X_test)[:,1]
fpr,tpr,threshold = roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
plt.show()
# Out:
# Accuracy : 88.46
# Precision : 0.9666666666666667
# Recall : 0.8923076923076924
# F1 Score : 0.928
# True Negative : 11
# False positive : 2
# False Negative : 7
# True Positive : 58

# %%
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()
NB.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = NB.predict(X_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [1 1 0 1 1]
# [1 0 0 1 1]

# %%
acc_NB = round(accuracy_score(y_test,y_pred)*100,2)
pre_NB = precision_score(y_test,y_pred)
rec_NB = recall_score(y_test,y_pred)
f1_NB = f1_score(y_test,y_pred)

print("Accuracy :",acc_NB)
print("Precision :",pre_NB)
print("Recall :",rec_NB)
print("F1 Score :",f1_NB)


cmt = confusion_matrix(y_test,y_pred)
cmt

disp = ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print("True Negative :",tn)
print("False positive :",fp)
print("False Negative :",fn)
print("True Positive :",tp)


y_pred_prob = NB.predict_proba(X_test)[:,1]
fpr,tpr,threshold = roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
plt.show()
# Out:
# Accuracy : 76.92
# Precision : 0.9607843137254902
# Recall : 0.7538461538461538
# F1 Score : 0.8448275862068965
# True Negative : 11
# False positive : 2
# False Negative : 16
# True Positive : 49

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = KNN.predict(X_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [1 1 0 1 1]
# [1 1 1 0 1]

# %%
acc_KNN = round(accuracy_score(y_test,y_pred)*100,2)
pre_KNN = precision_score(y_test,y_pred)
rec_KNN = recall_score(y_test,y_pred)
f1_KNN = f1_score(y_test,y_pred)

print("Accuracy :",acc_KNN)
print("Precision :",pre_KNN)
print("Recall :",rec_KNN)
print("F1 Score :",f1_KNN)


cmt = confusion_matrix(y_test,y_pred)
cmt

disp = ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print("True Negative :",tn)
print("False positive :",fp)
print("False Negative :",fn)
print("True Positive :",tp)


y_pred_prob = KNN.predict_proba(X_test)[:,1]
fpr,tpr,threshold = roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
plt.show()
# Out:
# Accuracy : 78.21
# Precision : 0.8428571428571429
# Recall : 0.9076923076923077
# F1 Score : 0.8740740740740741
# True Negative : 2
# False positive : 11
# False Negative : 6
# True Positive : 59

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = RF.predict(X_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [1 1 0 1 1]
# [1 1 0 1 1]

# %%
acc_RF = round(accuracy_score(y_test,y_pred)*100,2)
pre_RF = precision_score(y_test,y_pred)
rec_RF = recall_score(y_test,y_pred)
f1_RF = f1_score(y_test,y_pred)

print("Accuracy :",acc_RF)
print("Precision :",pre_RF)
print("Recall :",rec_RF)
print("F1 Score :",f1_RF)


cmt = confusion_matrix(y_test,y_pred)
cmt

disp = ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print("True Negative :",tn)
print("False positive :",fp)
print("False Negative :",fn)
print("True Positive :",tp)


y_pred_prob = RF.predict_proba(X_test)[:,1]
fpr,tpr,threshold = roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
plt.show()
# Out:
# Accuracy : 83.33
# Precision : 0.9193548387096774
# Recall : 0.8769230769230769
# F1 Score : 0.8976377952755904
# True Negative : 8
# False positive : 5
# False Negative : 8
# True Positive : 57

# %%
dict1 = {
    "Accuracy" : [acc_LR,acc_DT,acc_NB,acc_KNN,acc_RF],
    "Precision": [pre_LR,pre_DT,pre_NB,pre_KNN,pre_RF],
    "Recall" : [rec_LR,rec_DT,rec_NB,rec_KNN,rec_RF],
    "F1_Score":[f1_LR,f1_DT,f1_NB,f1_KNN,f1_RF]
}

output=pd.DataFrame(dict1,index = ["Logistic Regression","Decision Tree","Naive Bayes","KNN","Random Forest"])

output
# Out:
#                      Accuracy  Precision    Recall  F1_Score
# Logistic Regression     80.77   0.878788  0.892308  0.885496
# Decision Tree           88.46   0.966667  0.892308  0.928000
# Naive Bayes             76.92   0.960784  0.753846  0.844828
# KNN                     78.21   0.842857  0.907692  0.874074
# Random Forest           83.33   0.919355  0.876923  0.897638

# %%
# overall Decision Tree has good metrics

# %%
# Developing a model using Hyper Parameter

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
DT.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
param_grid = {
    "criterion" : ['gini','entropy'],
    "max_depth" : [3,4,5,6,7,8],
    "min_samples_split" : [2,3,4],
    "min_samples_leaf" : [1,2,3,4],
    "random_state" : [0,42]
    
}

# %%
grid_search = GridSearchCV(DT,param_grid,cv=4)
grid_search
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7, 8],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 4],
#                          'random_state': [0, 42]})

# %%
import time 

start_time = time.time()
grid_search.fit(X_train,y_train)
end_time = time.time()
print("the total time taken is :",(end_time-start_time))
# Out:
# the total time taken is : 10.476259469985962

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=3, random_state=0)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'random_state': 0}

# %%
grid_search.best_score_
# Out:
# 0.8678821178821178

# %%
from sklearn.tree import DecisionTreeClassifier
DTree = DecisionTreeClassifier(criterion = 'gini',
 max_depth= 3,
 min_samples_leaf= 3,
 min_samples_split= 2,
 random_state= 0)

DTree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=3, random_state=0)

# %%
y_pred = DTree.predict(X_test)

print(y_test.values[:5])
print(y_pred[:5])
# Out:
# [1 1 0 1 1]
# [1 1 0 1 1]

# %%
acc_DT = round(accuracy_score(y_test,y_pred)*100,2)
pre_DT = precision_score(y_test,y_pred)
rec_DT = recall_score(y_test,y_pred)
f1_DT = f1_score(y_test,y_pred)

print("Accuracy :",acc_DT)
print("Precision :",pre_DT)
print("Recall :",rec_DT)
print("F1 Score :",f1_DT)


cmt = confusion_matrix(y_test,y_pred)
cmt

disp = ConfusionMatrixDisplay(confusion_matrix=cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()

print("True Negative :",tn)
print("False positive :",fp)
print("False Negative :",fn)
print("True Positive :",tp)


y_pred_prob = DTree.predict_proba(X_test)[:,1]
fpr,tpr,threshold = roc_curve(y_test,y_pred_prob)
plt.plot(fpr,tpr)
plt.show()
# Out:
# Accuracy : 84.62
# Precision : 0.9649122807017544
# Recall : 0.8461538461538461
# F1 Score : 0.9016393442622951
# True Negative : 11
# False positive : 2
# False Negative : 10
# True Positive : 55

# %%
import pickle

# %%
pickle.dump(DTree,open("DTree2.pkl","wb"))
